# %% [markdown]
# The following illustration shows a generic base neural network model, Mp (Machine Learning model/ML-Model) trained on ImageNet dataset (Da). The base model is then used as the base for Transfer Learning, on Image Classification task (based on resnet18). The last layer of this pre-trained model (fully-connected/fc layer, A2) is then modified (to be A2') by a quantum means through a quantum machine learning framework: Pennylane.ai with a new dataset (Db), generating a new model (Mrt).
#
# The Quantum ML framework (which is open-source) provides convenient access to multiple quantum simulator and real quantum computer backend, including Pennylane's Lightning Qubit Device through an open-source Qiskit API (Application Programming Interface) accessible by Python programming language.

# %% [markdown]
# # 1. Preparation

# %% [markdown]
# ## Load required Python libraries

# %%
print("Installing libraries, this might take a while")

# !pip3 install -q torch
# !pip3 install -q pennylane
# !pip3 install -q matplotlib
# !pip3 install -q torchvision
# !pip3 install -q prettytable
# !pip3 install -q pennylane-qiskit

print("Building Simulator, this might take a while")

# !pip3 install pybind11 
# !pip3 install pennylane-lightning --no-binary :all: 
        
# System
import time
import os, platform, sys
import copy
from datetime import datetime

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms

# Pennylane
import pennylane as qml
from pennylane import numpy as np
from pennylane_qiskit import AerDevice

# Plotting
import matplotlib.pyplot as plt
# Out:
# Installing libraries, this might take a while
#      |████████████████████████████████| 1.0 MB 35.6 MB/s
#      |████████████████████████████████| 13.7 MB 61.0 MB/s
#      |████████████████████████████████| 145 kB 78.3 MB/s
#      |████████████████████████████████| 1.9 MB 52.8 MB/s
#      |████████████████████████████████| 3.3 MB 48.8 MB/s
#      |████████████████████████████████| 240 kB 71.9 MB/s
#      |████████████████████████████████| 272 kB 76.4 MB/s
#      |████████████████████████████████| 4.8 MB 60.6 MB/s
#      |████████████████████████████████| 19.2 MB 1.2 MB/s
#      |████████████████████████████████| 55 kB 4.1 MB/s
#      |████████████████████████████████| 106 kB 71.0 MB/s
#      |████████████████████████████████| 943 kB 64.4 MB/s
#      |████████████████████████████████| 37.5 MB 51 kB/s
#      |████████████████████████████████| 50 kB 8.3 MB/s
#      |████████████████████████████████| 49 kB 7.7 MB/s
#      |████████████████████████████████| 4.1 MB 61.7 MB/s
#      |████████████████████████████████| 112 kB 81.0 MB/s
#   Building wheel for qiskit (setup.py) ... done
# Building Simulator, this might take a while
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pybind11
#   Downloading pybind11-2.10.1-py3-none-any.whl (216 kB)
#      |████████████████████████████████| 216 kB 34.0 MB/s
# Installing collected packages: pybind11
# Successfully installed pybind11-2.10.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pennylane-lightning in /usr/local/lib/python3.7/dist-packages (0.26.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning) (1.11.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning) (1.21.6)
# Requirement already satisfied: pennylane>=0.19 in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning) (0.26.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (2.6.3)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (2.10.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (1.4.4)
# Requirement already satisfied: retworkx in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (0.12.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (0.10.2)
# Requirement already satisfied: autoray>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (0.5.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (4.2.4)
# Requirement already satisfied: autograd in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (1.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (1.7.3)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd->pennylane>=0.19->pennylane-lightning) (0.16.0)
# Requirement already satisfied: rustworkx==0.12.0 in /usr/local/lib/python3.7/dist-packages (from retworkx->pennylane>=0.19->pennylane-lightning) (0.12.0)

# %%
print("[Python version]:", sys.version)
print("[Deep Learning framework, Pytorch (Facebook) version]:", torch.__version__)
print("[Quantum Machine Learning framework (Pennylane) version]:", qml.__version__)
# Out:
# [Python version]: 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]
# [Deep Learning framework, Pytorch (Facebook) version]: 1.12.1+cu113
# [Quantum Machine Learning framework (Pennylane) version]: 0.26.0

# %%
# !unzip "brain_tumor_dataset.zip"
# Out:
# Archive:  brain_tumor_dataset.zip
#    creating: content/brain_tumor_dataset/
#    creating: content/brain_tumor_dataset/no_tumor/
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor95.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor15.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor34.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor24.jpg
#  extracting: content/brain_tumor_dataset/no_tumor/no_tumor35.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor16.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor2.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor82.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor89.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor55.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor54.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor91.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor49.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor29.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor44.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor68.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor27.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor65.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor26.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor74.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor93.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor57.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor81.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor5.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor36.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor0.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor48.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor72.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor25.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor18.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor17.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor7.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor79.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor78.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor28.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor40.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor64.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor32.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor76.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor75.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor33.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor46.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor23.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor85.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor4.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor87.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor67.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor56.jpg
#  extracting: content/brain_tumor_dataset/no_tumor/no_tumor60.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor10.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor11.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor86.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor62.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor92.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor20.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor19.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor9.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor38.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor51.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor80.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor3.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor84.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor71.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor22.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor21.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor83.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor90.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor94.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor47.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor61.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor66.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor12.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor50.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor41.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor45.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor59.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor8.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor88.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor52.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor58.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor31.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor42.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor53.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor69.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor63.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor70.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor43.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor39.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor37.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor1.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor30.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor77.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor96.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor73.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor97.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor6.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor14.jpg
#   inflating: content/brain_tumor_dataset/no_tumor/no_tumor13.jpg
#    creating: content/brain_tumor_dataset/.ipynb_checkpoints/
#    creating: content/brain_tumor_dataset/tumor/
#   inflating: content/brain_tumor_dataset/tumor/tumor97.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor112.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor99.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor77.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor147.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor21.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor2.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor142.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor144.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor135.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor6.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor106.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor145.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor29.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor51.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor25.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor116.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor82.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor30.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor37.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor45.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor76.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor100.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor91.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor139.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor148.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor87.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor69.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor124.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor73.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor75.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor61.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor46.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor66.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor128.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor26.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor53.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor111.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor70.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor84.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor143.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor7.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor44.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor140.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor122.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor93.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor94.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor57.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor153.jpg
#  extracting: content/brain_tumor_dataset/tumor/tumor141.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor58.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor86.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor39.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor150.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor49.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor131.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor127.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor33.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor34.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor78.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor74.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor35.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor79.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor115.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor138.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor109.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor23.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor65.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor132.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor92.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor146.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor120.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor19.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor12.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor107.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor38.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor89.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor56.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor36.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor9.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor20.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor52.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor3.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor134.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor95.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor11.jpg
#  extracting: content/brain_tumor_dataset/tumor/tumor152.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor62.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor5.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor103.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor8.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor16.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor118.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor130.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor28.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor126.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor149.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor72.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor27.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor14.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor81.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor85.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor108.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor43.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor114.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor63.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor117.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor90.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor60.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor137.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor71.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor105.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor13.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor67.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor96.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor50.jpg
#  extracting: content/brain_tumor_dataset/tumor/tumor55.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor121.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor4.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor48.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor15.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor18.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor47.jpg
#  extracting: content/brain_tumor_dataset/tumor/tumor17.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor102.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor154.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor133.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor98.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor40.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor136.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor54.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor110.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor31.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor64.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor88.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor32.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor10.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor104.jpg
#  extracting: content/brain_tumor_dataset/tumor/tumor129.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor59.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor83.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor80.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor0.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor1.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor68.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor42.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor22.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor41.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor125.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor113.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor151.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor119.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor123.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor24.jpg
#   inflating: content/brain_tumor_dataset/tumor/tumor101.jpg

# %%
#fix dataset
from tqdm import tqdm
import os

labels = ["tumor", "no_tumor"]
image_size = 150
num = 0
for i in labels:
  folderPath = os.path.join('/content/brain_tumor_dataset/',i)
  if i == "no_tumor":
    num = 0
    for j in tqdm(os.listdir(folderPath)):
      os.rename("/content/brain_tumor_dataset/no_tumor/" + j, "/content/brain_tumor_dataset/no_tumor/no_tumor" + str(num) + ".jpg")
      num += 1
  elif i == "tumor":
    num = 0
    for j in tqdm(os.listdir(folderPath)):
      os.rename("/content/brain_tumor_dataset/tumor/" + j, "/content/brain_tumor_dataset/tumor/tumor" + str(num) + ".jpg")
      num += 1
# Out:
# 100%|██████████| 155/155 [00:00<00:00, 23747.70it/s]
# 100%|██████████| 98/98 [00:00<00:00, 24557.40it/s]

# %% [markdown]
# ## Set Parameters

# %%
dataset_dir = "/content/bt_dataset"

num_epochs = 8                      # Number of training epochs (1 for testing, 8 for final)
n_qubits = 4                        # Number of qubits 
step = 0.0004                       # Learning rate
batch_size = 8                      # Number of samples for each training step
q_depth = 6                         # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1            # Learning rate reduction applied every 10 epochs.
q_delta = 0.01                      # Initial spread of random quantum weights
rng_seed = 3                        # Seed for random number generator
start_time = time.time()            # Start of the computation timer

model_fileext = ".pth"
log_fileext = ".log"

# %% [markdown]
# ## Define Backend: Quantum Simulator

# %%
backend_name = "simPennylane"
print("=> Using Lightning Pennylane Quantum Computer Simulator (local)")
dev = qml.device("lightning.qubit", wires=n_qubits)
# Out:
# => Using Lightning Pennylane Quantum Computer Simulator (local)

# %%
now = datetime.now()
now_str = now.strftime("%d%m%Y%H%M%S")

# model & log file name to generate
# swgCQ_resnet18_ + selected backend name + max epochs + current date & time + extension
#   - pytorch model file extension '.pth'
#   - log file for the generated model file extension '.log'
base_filename = "abrahimmahmud_"
interim_model_name = base_filename + backend_name 
hybrid_model_name = base_filename + backend_name + "(" + str(num_epochs) + ")-" + now_str + model_fileext
log_filename = base_filename + backend_name + "(" + str(num_epochs) + ")-" + now_str + log_fileext

train_val_filename = base_filename + backend_name + "_train_val-results" + now_str

# %%
# USE NVidia CUDA (GPU) if available
# ----------------------------------
is_cuda_available = torch.cuda.is_available()
device = torch.device("cuda:0" if is_cuda_available else "cpu")
if is_cuda_available:
    print ("cuda is available, using:", device)
else:
    print ("cuda is not available, using:", device)
# Out:
# cuda is available, using: cuda:0

# %% [markdown]
# ## Prepare new dataset to retrain last layer (fc-layer) of pre-trained resnet-18

# %%
# initialize data loaders
data_transforms = {
    "train": transforms.Compose(
        [
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            # Normalize input channels using mean values and standard deviations of ImageNet.
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
    "val": transforms.Compose(
        [
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
}

data_dir = dataset_dir
image_datasets = {
    x if x == "train" else "val": datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
    for x in ["train", "val"]
}
dataset_sizes = {x: len(image_datasets[x]) for x in ["train", "val"]}
class_names = image_datasets["train"].classes
# Initialize dataloader
dataloaders = {
    x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True)
    for x in ["train", "val"]
}

# function to plot images
def imshow(inp, title=None):
    """Display image from tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    # Inverse of the initial normalization operation.
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders["train"]))

print(np.shape(inputs))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

print(np.shape(out))

imshow(out, title=[class_names[x] for x in classes])

# In order to get reproducible results, we set a manual seed for the
# random number generator and re-initialize the dataloaders.

torch.manual_seed(rng_seed)
dataloaders = {
    x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True)
    for x in ["train", "val"]
}
# Out:
# torch.Size([8, 3, 224, 224])
# torch.Size([3, 228, 1810])

# %% [markdown]
# ## Define quantum layer to replace the fc-layer of pre-trained resnet-18

# %% [markdown]
# ### Variational Quantum Circuit

# %% [markdown]
# #### Define base quantum layers
# Define quantum layers that will compose the quantum circuit
# - Hadamard (for making superposition)
# - Ry & Entanglement

# %%
# 1st - Prepare the Quantum Gates
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)
        
def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)
        
def entangling_layer(nqubits):
    """Layer of CNOTs followed by another shifted layer of CNOT.
    """
    # In other words it should apply something like :
    # CNOT  CNOT  CNOT  CNOT...  CNOT
    #   CNOT  CNOT  CNOT...  CNOT
    for i in range(0, nqubits - 1, 2):  # Loop over even indices: i=0,2,...N-2
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):  # Loop over odd indices:  i=1,3,...N-3
        qml.CNOT(wires=[i, i + 1])

# %% [markdown]
# #### Define Quantum Circuit
# Define the quantum circuit through the PennyLane qnode decorator. The structure is that of a typical variational quantum circuit:
# - Embedding layer: All qubits are first initialized in a balanced superposition of up and down states, then they are rotated according to the input parameters (local embedding).
# - Variational layers: A sequence of trainable rotation layers and constant entangling layers is applied.
# - Measurement layer: For each qubit, the local expectation value of the
# Z operator is measured. This produces a classical output vector, suitable for additional post-processing.

# %%
@qml.qnode(dev, interface="torch")
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """
    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+> , unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)
    
    # Embed features in the quantum node
    RY_layer(q_input_features)
    
    # Sequence of trainable variational layers
    for k in range(q_depth):
        entangling_layer(n_qubits)
        RY_layer(q_weights[k])
        
    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %% [markdown]
# #### Define a custom torch.nn.Module representing a dressed quantum circuit.
#
# This is a concatenation of:
# - A classical pre-processing layer (nn.Linear)
# - A classical activation function (torch.tanh)
# - A constant np.pi/2.0 scaling
# - The previously defined quantum circuit (quantum_net)
# - A classical post-processing layer (nn.Linear)
#
# The input of the module is a batch of vectors with 512 real parameters (features) and the output is a batch of vectors with two real outputs (associated with the two classes of images: face_mask and face_nomask).

# %%
# 2nd - Prepare the Replacement Quantum Layer
class DressedQuantumNet(nn.Module):
    """
    Torch module implementing the *dressed* quantum net.
    """

    def __init__(self):
        """
        Definition of the *dressed* layout.
        """

        super().__init__()
        self.pre_net = nn.Linear(512, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, 2)

    def forward(self, input_features):
        """
        Defining how tensors are supposed to move through the *dressed* quantum
        net.
        """

        # obtain the input features for the quantum circuit
        # by reducing the feature dimension from 512 to 4
        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = quantum_net(elem, self.q_params).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %% [markdown]
# #### Build a full hybrid classical-quantum network
#
# Following the transfer learning approach:
#
# - load the classical pre-trained network ResNet18 from the torchvision.models zoo
# - freeze all the weights since they should not be trained
# - replace the last fully connected layer with our trainable dressed quantum circuit (DressedQuantumNet)

# %%
# 3rd - Replace last layer of resnet-18 with defined quantum layer
model_hybrid = torchvision.models.resnet18(pretrained=True)

for param in model_hybrid.parameters():
    param.requires_grad = False

# Notice that model_hybrid.fc is the last layer of ResNet18
model_hybrid.fc = DressedQuantumNet()

# Use CUDA or CPU according to the "device" object.
model_hybrid = model_hybrid.to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer_hybrid = optim.Adam(model_hybrid.fc.parameters(), lr=step)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_hybrid, step_size=10, gamma=gamma_lr_scheduler)

# %% [markdown]
# # 2. Retrain

# %% [markdown]
# ## Define how to retrain the DressedQuantumNet (last layer)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs, temp_model_name):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_loss = 10000.0  # Large arbitrary number
    best_acc_train = 0.0
    best_loss_train = 10000.0  # Large arbitrary number
    
    for epoch in range(num_epochs):
        # Each epoch has a training and validation phase
        for phase in ["train", "val"]:
            if phase == "train":
                # Set model to training mode
                model.train()
            else:
                # Set model to evaluate mode
                model.eval()
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            n_batches = dataset_sizes[phase] // batch_size
            it = 0
            for inputs, labels in dataloaders[phase]:
                since_batch = time.time()
                batch_size_ = len(inputs)
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()

                # Track/compute gradient and make an optimization step only when training
                with torch.set_grad_enabled(phase == "train"):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()

                # Print iteration results
                running_loss += loss.item() * batch_size_
                batch_corrects = torch.sum(preds == labels.data).item()
                running_corrects += batch_corrects
                message = "     > Phase: {} Epoch: {}/{} Iter: {}/{} Batch time: {:.4f}".format(
                                    phase,
                                    epoch + 1,
                                    num_epochs,
                                    it + 1,
                                    n_batches + 1,
                                    time.time() - since_batch,
                                 )
                # Print to screen with flush=True 
                print(message,
                        end="\r",
                        flush=True,
                )
                it += 1

            # Print epoch results
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
            message = "     > Phase: {} Epoch: {}/{} Loss: {:.4f} Acc: {:.4f}".format(
                                "train" if phase == "train" else "val  ",
                                epoch + 1,
                                num_epochs,
                                epoch_loss,
                                epoch_acc,
                            )

            # Check if this is the best model wrt previous epochs
            if phase == "val" and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == "val" and epoch_loss < best_loss:
                best_loss = epoch_loss
            if phase == "train" and epoch_acc > best_acc_train:
                best_acc_train = epoch_acc
            if phase == "train" and epoch_loss < best_loss_train:
                best_loss_train = epoch_loss

            train_Acc = "{:.4f}".format(best_acc_train)
            train_Loss = "{:.4f}".format(best_loss_train)
            val_Acc = "{:.4f}".format(best_acc)
            val_Loss = "{:.4f}".format(best_loss)
            
            # Update learning rate
            if phase == "train":
                scheduler.step()
        
        # save the retrained model at this epoch completion
        # epoch is saved as epoch+1 (so to start at 1 instead of 0)
        # ---------------------------------------------------------
        model_at_epoch = temp_model_name + "-at-epoch-"+ str(epoch+1) \
            + "(" + str(num_epochs) + ")-" + now_str + model_fileext
        torch.save(model_hybrid.state_dict(), model_at_epoch)
        
        # save results of trained model at this epoch
        # ------------------------------------------- 
        # append list of "epoch, train accuracy, train loss, val accuracy, val loss" per epoch completion
        #   accumulate in train_val_results
        if epoch==0:
            # create first row
            train_val_results = np.array([[epoch+1, best_acc_train, best_loss_train, best_acc, best_loss]])
        else:
            train_result_at_epoch = np.array([[epoch+1, best_acc_train, best_loss_train, best_acc, best_loss]])
            # append new row
            train_val_results = np.append(train_val_results, train_result_at_epoch, axis=0) 
        
    # Write train_val_results to file
    np.save(train_val_filename, train_val_results)
    
    # Print final results
    model.load_state_dict(best_model_wts)
    time_elapsed = time.time() - since
    total_training_time = "{:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60)
    total_training_time = "{:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60)
    return model, total_training_time, train_Acc, train_Loss, val_Acc, val_Loss, train_val_results

# %% [markdown]
# ## Re-train the quantum layer

# %%
model_hybrid, total_training_time, train_Acc, train_Loss, val_Acc, val_Loss, train_val_results = train_model(
    model_hybrid, criterion, optimizer_hybrid, exp_lr_scheduler, num_epochs=num_epochs, temp_model_name = interim_model_name)

# %%
# SAVE final retrained Resnet-18 model
# ------------------------------------
torch.save(model_hybrid.state_dict(), hybrid_model_name)

# %%
# PRINT training summary
# ----------------------
from prettytable import PrettyTable
    
t_summary = PrettyTable()
t_summary.field_names = ["QC backend", "epoch", "batch size", \
    "train time", "train Acc", "train Loss", "val Acc", "val Loss"]
t_summary.add_row([backend_name, num_epochs, batch_size, \
    total_training_time, train_Acc, train_Loss, val_Acc, val_Loss])

# %%
for x in train_val_results:
    print(x)
# Out:
# [1.         0.62204724 0.65908372 0.76190476 0.59628929]
# [2.         0.65354331 0.61789648 0.76190476 0.59628929]
# [3.         0.77165354 0.54784993 0.76190476 0.53633777]
# [4.         0.77165354 0.54784993 0.80952381 0.49732129]
# [5.         0.77165354 0.51115794 0.80952381 0.47050589]
# [6.         0.79527559 0.48195163 0.85714286 0.46976189]
# [7.         0.81889764 0.48195163 0.85714286 0.43680206]
# [8.         0.83464567 0.45213249 0.85714286 0.43680206]

# %%
epoch = []
train_acc = []
train_loss = []
val_acc =[]
val_loss = []

for i in range(0, len(train_val_results)):
    epoch = np.append(epoch, train_val_results[i,0])
    train_acc = np.append(train_acc, train_val_results[i,1])
    train_loss = np.append(train_loss, train_val_results[i,2])    
    val_acc = np.append(val_acc, train_val_results[i,3])
    val_loss = np.append(val_loss, train_val_results[i,4])

# %%
# PLOT graph - training/validation accuracy, loss
# -----------------------------------------------
x1 = epoch
x2 = epoch
y1 = train_acc
y2 = val_acc

# plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('Training Summary: ' + backend_name)
plt.ylabel('train/val accuracy')

# plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('Epoch')
# plt.ylabel('train/val accuracy')

plt.legend(["train accuracy","val accuracy"])
plt.show()

# %%
# PLOT graph - training/validation accuracy, loss
# -----------------------------------------------
y1 = train_loss
y2 = val_loss

# plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('Training Summary: ' + backend_name)
plt.ylabel('train/val loss')

# plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('Epoch')
# plt.ylabel('train/val loss')

plt.legend(["train loss","val loss"])
plt.show()

# %%
# INSPECT the retrained Resnet-18 model neural network architecture
# -----------------------------------------------------------------
model_arch = model_hybrid.eval()

# %% [markdown]
# # 3. Test/Predict using the re-trained model

# %%
def visualize_model(model, num_images=4, fig_name="Predictions"):
    images_so_far = 0
    _fig = plt.figure(fig_name, figsize=(15,15))
    model.eval()
    with torch.no_grad(): # inferencing
        for _i, (inputs, labels) in enumerate(dataloaders["val"]):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            # Expectation value is probabilistic expected value of the result (measurement) of an experiment
            # Pennylane implements the quantum measurement in such a way that:
            #  - if the first qubit is non zero, it puts negative to the measurement
            # expvals is expectation value of predicted class
            expvals, preds = torch.max(outputs, 1)
            # expvals_min is expectation value of another class as we only have 2 image classes/categories here
            expvals_min, preds_min = torch.min(outputs, 1)
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis("off")
                title = "Detected as <" + class_names[preds[j]] + ">, Expectation Value: " + \
                    "{:.5f}".format(expvals[j]) + " (" + \
                    "{:.5f}".format(expvals_min[j]) + ")" 
                ax.set_title("[{}]".format(title))
                imshow(inputs.cpu().data[j])
                if images_so_far == num_images:
                    return

# %%
visualize_model(model_hybrid, num_images=4, fig_name="Predictions")
plt.show()

# %% [markdown]
# # Save and Load Hybrid Model

# %%
torch.save(model_hybrid, 'hybrid_model.h5')

# %%
test_model = torch.load('/content/hybrid_model.h5')
